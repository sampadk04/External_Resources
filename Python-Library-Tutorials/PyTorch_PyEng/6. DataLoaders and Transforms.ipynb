# %% [markdown]
# # 1. Imports

# %%
# importing other dependencies
import numpy as np
import pandas as pd
# importing PyTorch
import torch
# importing torch.nn Module
import torch.nn as nn
# importing Dataset, DataLoader
from torch.utils.data import Dataset, DataLoader, TensorDataset
# import Compose to compose transforms
from torchvision.transforms import Compose
# plotting
import matplotlib.pyplot as plt

# %%
# checks whether MPS is available
print(torch.backends.mps.is_available())

# this ensures that the current current PyTorch installation was built with MPS activated.
print(torch.backends.mps.is_built())

# setting the device to "mps" instead of default "cpu"
device = torch.device("mps" if torch.backends.mps.is_available else "cpu")
# Out:
# True
# True

# %% [markdown]
# # 2. DataLoaders
#
# Prediction, calculation of loss and gradient computation can be expensive on large datasets. This can be solved by loading the data in smaller batches. We follow the steps for a single mini-batch and update the weights accordingly.
#
# Some terminology:
# - **epoch**: one forward and backward pass of *all* training samples
# - **batch_size**: number of training samples used in one forward/backward pass
# - **#iterations**: number of passes, each pass (forward+backward) using [batch_size] number of samples
# - **Example**: 100 samples, batch_size=20 -> 100/20=5 iterations for 1 epoch
#
#
# This is going to be the template now:
# ```Python
# # training loop
# for epoch in range(num_epochs):
#     # loop over all the mini-batches:
#     for i in range(total_batches):
#         batch_X, batch_y = ...
# ```
#
# DataLoader can do batch computation for us. Before we do that, we implement a custom Dataset class.

# %% [markdown]
# ## 2.1 Wine Dataset

# %% [markdown]
# In this example, we will be loading the `Wine Dataset` by reading the `.csv` file via the custom Dataset class that we will be implementing.

# %%
data_df = pd.read_csv('data/wine.csv')
data_df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
# Implementing a custom Dataset:
#   inherit 'Dataset' class
#   implement:
#       - __init__: to define the variables
#       - __getitem__: to onbtain (x,y) from a certain index
#       - __len__: to get the length of the dataset, or get #samples


# custom class for wine dataset

class WineDataset(Dataset):
    def __init__(self):
        # initialize data, download etc.
        # read with numpy or pandas
        df = pd.read_csv('data/wine.csv')
        
        # extract features and target
        features = df.drop('Wine', axis=1).values
        target = df[['Wine']].values
        
        # convert to pytorch tensor (after converting it to float32) using TensorDataset
        data_tensor = TensorDataset(
            torch.tensor(features, dtype=torch.float32),
            torch.tensor(target, dtype=torch.float32)
        )
        # TensorDataset is not exactly a tensor but each row looks like (x,y) tuples

        # extract the no. of samples
        self.n_samples = len(data_tensor)
        
        # extract features and target
        self.X = data_tensor[:][0] # size [n_samples, n_features]
        self.y = data_tensor[:][1] # size [n_samples, 1]
    
    # support indexing such that dataset[i] can be used to obtain the i-th sample
    def __getitem__(self, index):
        # return tuple (xi,yi)
        return self.X[index], self.y[index]

    # we can also obtain n_samples by calling length of the dataset
    def __len__(self):
        return self.n_samples

# %% [markdown]
# Now that we have created the custom `WineDataset` class, we can wrap it via `DataLoader` to extract data in batches.

# %%
# create dataset
dataset = WineDataset()

# get first sample and unpack
first_data = dataset[0]
x0, y0 = first_data
print(x0, y0)
# Out:
# tensor([1.4230e+01, 1.7100e+00, 2.4300e+00, 1.5600e+01, 1.2700e+02, 2.8000e+00,
#         3.0600e+00, 2.8000e-01, 2.2900e+00, 5.6400e+00, 1.0400e+00, 3.9200e+00,
#         1.0650e+03]) tensor([1.])

# %%
# create dataset
dataset = WineDataset()

# Load whole dataset with DataLoader
# shuffle: shuffle data for good training
train_loader = DataLoader(
    dataset=dataset,
    batch_size=4,
    shuffle=True,
)

# %%
# we can also convert the DataLoader into an iterator and extract the data one batch at a time
train_iter = iter(train_loader)
data_batch = next(train_iter)

features, targets = data_batch
print("Batch_X:\n",features)
print("Batch_y:\n", targets)
print("Shapes:", features.shape, targets.shape)
# Out:
# Batch_X:
#  tensor([[1.2290e+01, 1.4100e+00, 1.9800e+00, 1.6000e+01, 8.5000e+01, 2.5500e+00,
#          2.5000e+00, 2.9000e-01, 1.7700e+00, 2.9000e+00, 1.2300e+00, 2.7400e+00,
#          4.2800e+02],
#         [1.1650e+01, 1.6700e+00, 2.6200e+00, 2.6000e+01, 8.8000e+01, 1.9200e+00,
#          1.6100e+00, 4.0000e-01, 1.3400e+00, 2.6000e+00, 1.3600e+00, 3.2100e+00,
#          5.6200e+02],
#         [1.2820e+01, 3.3700e+00, 2.3000e+00, 1.9500e+01, 8.8000e+01, 1.4800e+00,
#          6.6000e-01, 4.0000e-01, 9.7000e-01, 1.0260e+01, 7.2000e-01, 1.7500e+00,
#          6.8500e+02],
#         [1.3410e+01, 3.8400e+00, 2.1200e+00, 1.8800e+01, 9.0000e+01, 2.4500e+00,
#          2.6800e+00, 2.7000e-01, 1.4800e+00, 4.2800e+00, 9.1000e-01, 3.0000e+00,
#          1.0350e+03]])
# Batch_y:
#  tensor([[2.],
#         [2.],
#         [3.],
#         [1.]])
# Shapes: torch.Size([4, 13]) torch.Size([4, 1])

# %% [markdown]
# ## 2.2 Dummy Training Loop

# %%
# dummy training loop with DataLoaders

dataset = WineDataset()

num_epochs = 2
n_samples = len(dataset)

train_loader = DataLoader(
    dataset=dataset,
    batch_size=4,
    shuffle=True,
    num_workers=0
)

for epoch in range(num_epochs):
    for (idx, batch) in enumerate(train_loader):
        # extract feature and labels
        features, targets = batch

        # run your training processes here: forward, backward, update
        
        # print info after every 5 mini-batches
        if idx%5 == 0:
            print('-------------------------------')
            print(f'Epoch: {epoch+1}/{num_epochs}')
            print(f'Steps: {idx+1}')
            print(f'Batch Features shape: {features.shape} | Batch Target shape: {targets.shape}')
# Out:
# -------------------------------
# Epoch: 1/2
# Steps: 1
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 1/2
# Steps: 6
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 1/2
# Steps: 11
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 1/2
# Steps: 16
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 1/2
# Steps: 21
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 1/2
# Steps: 26
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 1/2
# Steps: 31
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 1/2
# Steps: 36
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 1/2
# Steps: 41
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 2/2
# Steps: 1
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 2/2
# Steps: 6
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 2/2
# Steps: 11
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 2/2
# Steps: 16
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 2/2
# Steps: 21
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 2/2
# Steps: 26
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 2/2
# Steps: 31
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 2/2
# Steps: 36
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])
# -------------------------------
# Epoch: 2/2
# Steps: 41
# Batch Features shape: torch.Size([4, 13]) | Batch Target shape: torch.Size([4, 1])

# %% [markdown]
# # 3. Data Transforms
#
# There are many data transform techniques. The complete list of built-in transforms in PyTorch can be found [here](https://pytorch.org/vision/stable/transforms.html).
#
# - On **Images**:
#     - `CenterCrop`, `Grayscale`, `Pad`, `RandomAffine`
#     - `RandomCrop`, `RandomHorizontalFlip`, `RandomRotation`
#     - `Resize`, `Scale`
#
# - On **Tensors**:
#     - `LinearTransformation`, `Normalize`, `RandomErasing`
#
# - **Conversion**:
#     - `ToPILImage`: from tensor or ndrarray
#     - `ToTensor` : from numpy.ndarray or PILImage
#
# - **Generic**:
#     - use `Lambda`
#
# - **Custom**:
#     - write own `class`
#
# - **Composing multiple Transforms**:
# ```Python
# from torchvision.transforms import Compose
# compose = Compose(
#     [transform_1],
#     [transform_2],
#     ...
# )
# ```

# %% [markdown]
# We can implement `Transforms` into the custom Dataset class itself. We again use the `wine.csv` dataset for this purpose.

# %%
# Implementing a custom Dataset:
#   inherit 'Dataset' class
#   implement:
#       - __init__: to define the variables
#       - __getitem__: to onbtain (x,y) from a certain index
#       - __len__: to get the length of the dataset, or get #samples


# custom class for wine dataset

class WineDataset(Dataset):
    def __init__(self, transform = None):
        # initialize data, download etc.
        # read with numpy or pandas
        df = pd.read_csv('data/wine.csv')
        
        # extract features and target
        self.X = df.drop('Wine', axis=1).values
        self.y = df[['Wine']].values
        # we do not convert to tensor here

        # extract the transform into a variable
        self.transform = transform

        # extract the no. of samples
        self.n_samples = df.shape[0]

    
    # support indexing such that dataset[i] can be used to obtain the i-th sample
    def __getitem__(self, index):
        feature = self.X[index].reshape(1,-1)
        target = self.y[index].reshape(-1,1)

        # if transform is not `None`
        if self.transform:
            feature = self.transform(feature)
            target = self.transform(target)
        
        return feature, target

    # we can also obtain n_samples by calling length of the dataset
    def __len__(self):
        return self.n_samples

# %% [markdown]
# ## 3.1 Without Transforms

# %% [markdown]
# Note that by default without any transforms, these will give numpy arrays as output.

# %%
# create dataset without transform
dataset = WineDataset()

# get first sample and unpack
first_data = dataset[0]
x0, y0 = first_data
print(x0, y0)
print(type(x0), type(y0))
print(x0.shape, y0.shape)
# Out:
# [[1.423e+01 1.710e+00 2.430e+00 1.560e+01 1.270e+02 2.800e+00 3.060e+00
#   2.800e-01 2.290e+00 5.640e+00 1.040e+00 3.920e+00 1.065e+03]] [[1]]
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (1, 13) (1, 1)

# %% [markdown]
# ## 3.2 With Transforms

# %% [markdown]
# In this case, we first we convert the samples into PyTorch tensors from numpy arrays. For this we use the built-in `ToTensor` method.

# %%
from torchvision.transforms import ToTensor

# create dataset with transform
dataset = WineDataset(transform=ToTensor())

# get first sample and unpack
first_data = dataset[0]
x0, y0 = first_data
print(x0, y0)
print(type(x0), type(y0))
print(x0.shape, y0.shape)
# Out:
# tensor([[[1.4230e+01, 1.7100e+00, 2.4300e+00, 1.5600e+01, 1.2700e+02,
#           2.8000e+00, 3.0600e+00, 2.8000e-01, 2.2900e+00, 5.6400e+00,
#           1.0400e+00, 3.9200e+00, 1.0650e+03]]], dtype=torch.float64) tensor([[[1]]])
# <class 'torch.Tensor'> <class 'torch.Tensor'>
# torch.Size([1, 1, 13]) torch.Size([1, 1, 1])

# %% [markdown]
# Notice that the numpy arrays have been converted to PyTorch Tensors.

# %% [markdown]
# ## 3.3 Custom Transforms

# %% [markdown]
# We can create custom transforms by either modifying the in-built methods, by modifying the `__call__` attribute in them, or building a transform class from scratch.

# %% [markdown]
# Suppose, we decide to modify the `ToTensor()` method.

# %%
# Implementing a custom Dataset:
#   inherit 'Dataset' class
#   implement:
#       - __init__: to define the variables
#       - __getitem__: to onbtain (x,y) from a certain index
#       - __len__: to get the length of the dataset, or get #samples


# custom class for wine dataset

class WineDataset(Dataset):
    def __init__(self, transform = None):
        # initialize data, download etc.
        # read with numpy or pandas
        df = pd.read_csv('data/wine.csv')
        
        # extract features and target
        self.X = df.drop('Wine', axis=1).values
        self.y = df[['Wine']].values
        # we do not convert to tensor here

        # extract the transform into a variable
        self.transform = transform

        # extract the no. of samples
        self.n_samples = df.shape[0]


    # support indexing such that dataset[i] can be used to obtain the i-th sample
    def __getitem__(self, index):
        sample = self.X[index], self.y[index]

        # if transform is not `None`
        if self.transform:
            sample = self.transform(sample)
        
        return sample
        

    # we can also obtain n_samples by calling length of the dataset
    def __len__(self):
        return self.n_samples

# %%
# modify the `ToTensor` method:
class ToTensor:
    # converting numpy arrays to Tensors
    def __call__(self, sample):
        feature, target = sample
        # convert them to Tendors
        feature = torch.from_numpy(feature.astype(np.float32))
        target = torch.from_numpy(target.astype(np.float32))
        return feature, target

# %%
# create dataset with transform
dataset = WineDataset(transform=ToTensor())

# get first sample and unpack
first_data = dataset[0]
x0, y0 = first_data
print(x0, y0)
print(type(x0), type(y0))
print(x0.shape, y0.shape)
# Out:
# tensor([1.4230e+01, 1.7100e+00, 2.4300e+00, 1.5600e+01, 1.2700e+02, 2.8000e+00,
#         3.0600e+00, 2.8000e-01, 2.2900e+00, 5.6400e+00, 1.0400e+00, 3.9200e+00,
#         1.0650e+03]) tensor([1.])
# <class 'torch.Tensor'> <class 'torch.Tensor'>
# torch.Size([13]) torch.Size([1])

# %% [markdown]
# Similarly, we can also decide to create a new transform method, say `MulTransform()`, which takes in a float as an argument and multiplies that to all the input features.

# %%
# create a new transform class
class MulTransform:
    # this takes in a no. as an arg
    def __init__(self, factor=1):
        self.factor = factor
    
    # multiplying factor to the input features
    def __call__(self, sample):
        feature, target = sample
        feature *= self.factor
        return feature, target

# %%
# create dataset with transform
dataset = WineDataset(transform=MulTransform(factor=2))

# get first sample and unpack
first_data = dataset[0]
x0, y0 = first_data
print(x0, y0)
print(type(x0), type(y0))
print(x0.shape, y0.shape)
# Out:
# [2.846e+01 3.420e+00 4.860e+00 3.120e+01 2.540e+02 5.600e+00 6.120e+00
#  5.600e-01 4.580e+00 1.128e+01 2.080e+00 7.840e+00 2.130e+03] [1]
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (13,) (1,)

# %% [markdown]
# Note, that the samples are still numpy arrays.

# %% [markdown]
# ## 3.4 Composing Transforms

# %% [markdown]
# Suppose, we want to compose 2 transforms `ToTensor()` and `MulTransform()`. We can do this by using `torchvision.transforms.Compose()`.

# %%
from torchvision.transforms import Compose

composedTransform = Compose([
    ToTensor(),
    MulTransform(factor=2)
])

# %%
# create dataset with transform
dataset = WineDataset(transform=composedTransform)

# get first sample and unpack
first_data = dataset[0]
x0, y0 = first_data
print(x0, y0)
print(type(x0), type(y0))
print(x0.shape, y0.shape)
# Out:
# tensor([2.8460e+01, 3.4200e+00, 4.8600e+00, 3.1200e+01, 2.5400e+02, 5.6000e+00,
#         6.1200e+00, 5.6000e-01, 4.5800e+00, 1.1280e+01, 2.0800e+00, 7.8400e+00,
#         2.1300e+03]) tensor([1.])
# <class 'torch.Tensor'> <class 'torch.Tensor'>
# torch.Size([13]) torch.Size([1])

# %% [markdown]
# Notice, that these have been multiplied by a factor of 2 and have also been converted to PyTorch Tensors.

# %% [markdown]
# # 4. Full Pipeline
#
# We train a Logistic Regression model on the Breast Cancer dataset using the techniques above.

# %% [markdown]
# ## 4.1 Preparing Data

# %% [markdown]
# ### 4.1.1 Creating the Dataset Class

# %% [markdown]
# Note: Inorder to fit a regression model, we need to standard scale the data to make the model fit properly.

# %%
# Implementing a custom Dataset:
#   inherit 'Dataset' class
#   implement:
#       - __init__: to define the variables
#       - __getitem__: to onbtain (x,y) from a certain index
#       - __len__: to get the length of the dataset, or get #samples


# custom class for Breast Cancer dataset

from torch.utils.data import Dataset
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler

class BCDataset(Dataset):
    def __init__(self, transform = None):
        # initialize data, download etc.
        # read with numpy or pandas
        
        # extract features and target
        self.X, self.y = load_breast_cancer(return_X_y=True)
        
        # reshape y
        self.y = self.y.reshape(-1,1)
        
        # standard scale X
        ss = StandardScaler()
        self.X = ss.fit_transform(self.X)

        # we do not convert to tensor here

        # extract the transform into a variable
        self.transform = transform

        # extract the no. of samples
        self.n_samples = self.X.shape[0]

        # extract the no. of input features
        self.n_features = self.X.shape[1]


    # support indexing such that dataset[i] can be used to obtain the i-th sample
    def __getitem__(self, index):
        sample = self.X[index], self.y[index]

        # if transform is not `None`
        if self.transform:
            sample = self.transform(sample)
        
        return sample
        

    # we can also obtain n_samples by calling length of the dataset
    def __len__(self):
        return self.n_samples

# %% [markdown]
# We define some custom Transforms here.

# %%
from torchvision.transforms import ToTensor

# modify the `ToTensor` method:
class ToTensor:
    # converting numpy arrays to Tensors
    def __call__(self, sample):
        feature, target = sample
        # convert them to Tendors
        feature = torch.from_numpy(feature.astype(np.float32))
        target = torch.from_numpy(target.astype(np.float32))
        return feature, target

# %%
# create dataset with transform
dataset = BCDataset(transform=ToTensor())

# %% [markdown]
# ### 4.1.2 Splitting into Training and Test Datasets
#
# Inorder to split the dataset we need to use `torch.utils.data.random_split()` method, before feeding the training data into a DataLoader.

# %%
from torch.utils.data import random_split

# determining the train,test size
n_samples = len(dataset)
test_ratio = 0.1

test_size = int(n_samples*test_ratio)
train_size = n_samples - test_size

train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

print("Training Dataset Size:", len(train_dataset))
print("Test Dataset Size:", len(test_dataset))
# Out:
# Training Dataset Size: 513
# Test Dataset Size: 56

# %% [markdown]
# ### 4.1.3 Feeding into DataLoader

# %%
from torch.utils.data import DataLoader

# for the test dataset, we consider the full batch size for evaluation purposes, hence batch_size=len(test_dataset) and shuffle = False
test_loader = DataLoader(
    dataset=test_dataset,
    batch_size=len(test_dataset),
    shuffle=False,
    num_workers=0
)

# we use an iterator to extract the full batch of test dataset
X_test, y_test = next(iter(test_loader))
print(X_test.shape, y_test.shape)

# set the batch_size
batch_size = 5

# for the train dataset, we split this into batches of size 4
train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0   
)
# Out:
# torch.Size([56, 30]) torch.Size([56, 1])

# %% [markdown]
# ## 4.2 Creating the Model

# %%
class LogisticRegression(nn.Module):
    def __init__(self, input_dim):
        super(LogisticRegression, self).__init__()

        # define the layers here
        self.linear = nn.Linear(input_dim, 1)
        # here output dim is going to be 1
    
    def forward(self, X):
        # we use sigmoid activation
        y_hat = torch.sigmoid(self.linear(X))
        return y_hat

# %%
input_dim = dataset.n_features

# initialise linear regression model instance
model = LogisticRegression(input_dim)

# %%
# we also check the initial loss on the test data before training

from sklearn.metrics import accuracy_score

with torch.no_grad():
    # this gives the sigmoid output
    y_test_pred = model(X_test)
    # this assigns 1 if sigmoid op is >=0.5 and 0 o.w.
    y_test_hat = y_test_pred.round()
    print("Initial Accuracy on test data:", accuracy_score(y_test, y_test_hat))
# Out:
# Initial Accuracy on test data: 0.07142857142857142

# %% [markdown]
# ## 4.3 Training

# %%
# in this scenario, we use the MSE Loss, with SGD optimization

# learning rate
lr = 0.01

# no. of epochs
num_epochs = 300

# define loss criterion: Binary Cross Entropy loss
criterion = nn.BCELoss()

# define optimizer
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# format of optimizer: torch.optim.SGD(weights, lr, ...)

# %%
for epoch in range(num_epochs):
    # load training data in batched via train_loader
    for (idx, batch) in enumerate(train_loader):
        # extract features and labels
        X_train_batch, y_train_batch = batch

        # training processes
        # forward pass:
        # compute prediction
        y_train_batch_pred = model(X_train_batch)
        # compute loss
        loss = criterion(y_train_batch_pred, y_train_batch)

        # backward pass:
        # compute gradients
        loss.backward()

        # update weights:
        optimizer.step()
        # zero-gradients after updating
        optimizer.zero_grad()

        # print info after every 5 mini-batches
        if idx%5 == 0:
            print('-------------------------------')
            print(f'Epoch: {epoch+1}/{num_epochs}')
            print(f'Steps: {idx+1}')
            print(f'Batch Features shape: {X_train_batch.shape} | Batch Target shape: {y_train_batch.shape}')
            print(f'Loss: {loss}')
# Out:
# -------------------------------
# Epoch: 1/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.9560569524765015
# -------------------------------
# Epoch: 1/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.8834799528121948
# -------------------------------
# Epoch: 1/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.6790915131568909
# -------------------------------
# Epoch: 1/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.5666138529777527
# -------------------------------
# Epoch: 1/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.61336749792099
# -------------------------------
# Epoch: 1/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.5747867226600647
# -------------------------------
# Epoch: 1/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.49643248319625854
# -------------------------------
# Epoch: 1/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.4575059413909912
# -------------------------------
# Epoch: 1/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.5139877796173096
# -------------------------------
# Epoch: 1/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.39371997117996216
# -------------------------------
# Epoch: 1/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3528466522693634
# -------------------------------
# Epoch: 1/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3167356848716736
# -------------------------------
# Epoch: 1/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.29353559017181396
# -------------------------------
# Epoch: 1/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3355883061885834
# -------------------------------
# Epoch: 1/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.25057679414749146
# -------------------------------
# Epoch: 1/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3590800166130066
# -------------------------------
# Epoch: 1/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.09781128913164139
# -------------------------------
# Epoch: 1/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3469504415988922
# -------------------------------
# Epoch: 1/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.523659348487854
# -------------------------------
# Epoch: 1/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.658364474773407
# -------------------------------
# Epoch: 1/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.14304614067077637
# -------------------------------
# Epoch: 2/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.256568968296051
# -------------------------------
# Epoch: 2/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.22418232262134552
# -------------------------------
# Epoch: 2/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.2532487213611603
# -------------------------------
# Epoch: 2/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.20718355476856232
# -------------------------------
# Epoch: 2/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.4624995291233063
# -------------------------------
# Epoch: 2/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.15647634863853455
# -------------------------------
# Epoch: 2/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.36738649010658264
# -------------------------------
# Epoch: 2/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1967421919107437
# -------------------------------
# Epoch: 2/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3200439214706421
# -------------------------------
# Epoch: 2/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3606800436973572
# -------------------------------
# Epoch: 2/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1450941562652588
# -------------------------------
# Epoch: 2/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.19215309619903564
# -------------------------------
# Epoch: 2/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.29584190249443054
# -------------------------------
# Epoch: 2/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.2534481883049011
# -------------------------------
# Epoch: 2/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.20594267547130585
# -------------------------------
# Epoch: 2/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.24189519882202148
# -------------------------------
# Epoch: 2/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.28539586067199707
# -------------------------------
# Epoch: 2/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3353918194770813
# -------------------------------
# Epoch: 2/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.20217165350914001
# -------------------------------
# Epoch: 2/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07539946585893631
# -------------------------------
# Epoch: 2/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04447083920240402
# -------------------------------
# Epoch: 3/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1407977044582367
# -------------------------------
# Epoch: 3/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.2706167697906494
# -------------------------------
# Epoch: 3/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.2506629526615143
# -------------------------------
# Epoch: 3/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.09070505201816559
# -------------------------------
# Epoch: 3/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.21646201610565186
# -------------------------------
# Epoch: 3/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3006103038787842
# -------------------------------
# Epoch: 3/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07987058907747269
# -------------------------------
# Epoch: 3/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3971770107746124
# -------------------------------
# Epoch: 3/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.16306328773498535
# -------------------------------
# Epoch: 3/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.11091639846563339
# -------------------------------
# Epoch: 3/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.11756100505590439
# -------------------------------
# Epoch: 3/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.14953331649303436
# -------------------------------
# Epoch: 3/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.37968483567237854
# -------------------------------
# Epoch: 3/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.06949641555547714
# -------------------------------
# Epoch: 3/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.06734878569841385
# -------------------------------
# Epoch: 3/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.09117064625024796
# -------------------------------
# Epoch: 3/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3415347635746002
# -------------------------------
# Epoch: 3/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.14195740222930908
# -------------------------------
# Epoch: 3/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.31041714549064636
# -------------------------------
# Epoch: 3/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.14483767747879028
# -------------------------------
# Epoch: 3/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.12370232492685318
# -------------------------------
# Epoch: 4/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07383446395397186
# -------------------------------
# Epoch: 4/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.20674142241477966
# -------------------------------
# Epoch: 4/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.12865093350410461
# -------------------------------
# Epoch: 4/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.05403125286102295
# -------------------------------
# Epoch: 4/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.044342927634716034
# -------------------------------
# Epoch: 4/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.4435262680053711
# -------------------------------
# Epoch: 4/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04840525612235069
# -------------------------------
# Epoch: 4/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08082666248083115
# -------------------------------
# Epoch: 4/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.18971391022205353
# -------------------------------
# Epoch: 4/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08129508793354034
# -------------------------------
# Epoch: 4/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08508454263210297
# -------------------------------
# Epoch: 4/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.10746772587299347
# -------------------------------
# Epoch: 4/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.20137397944927216
# -------------------------------
# Epoch: 4/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1361093670129776
# -------------------------------
# Epoch: 4/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1183319091796875
# -------------------------------
# Epoch: 4/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.14908252656459808
# -------------------------------
# Epoch: 4/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1330481767654419
# -------------------------------
# Epoch: 4/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.2451169490814209
# -------------------------------
# Epoch: 4/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04087375849485397
# -------------------------------
# Epoch: 4/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0976300984621048
# -------------------------------
# Epoch: 4/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1396462619304657
# -------------------------------
# Epoch: 5/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3453834354877472
# -------------------------------
# Epoch: 5/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.10066428035497665
# -------------------------------
# Epoch: 5/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.11142992973327637
# -------------------------------
# Epoch: 5/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1984677016735077
# -------------------------------
# Epoch: 5/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03824423998594284
# -------------------------------
# Epoch: 5/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.38216012716293335
# -------------------------------
# Epoch: 5/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.10280191898345947
# -------------------------------
# Epoch: 5/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3429952561855316
# -------------------------------
# Epoch: 5/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03274242579936981
# -------------------------------
# Epoch: 5/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08233250677585602
# -------------------------------
# Epoch: 5/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.24362942576408386
# -------------------------------
# Epoch: 5/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07222539186477661
# -------------------------------
# Epoch: 5/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04224300757050514
# -------------------------------
# Epoch: 5/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04052751138806343
# -------------------------------
# Epoch: 5/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.038871802389621735
# -------------------------------
# Epoch: 5/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.34489625692367554
# -------------------------------
# Epoch: 5/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07833658158779144
# -------------------------------
# Epoch: 5/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.09304455667734146
# -------------------------------
# Epoch: 5/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0466240718960762
# -------------------------------
# Epoch: 5/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.074353888630867
# -------------------------------
# Epoch: 5/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.06563188135623932
# -------------------------------
# Epoch: 6/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.2758164405822754
# -------------------------------
# Epoch: 6/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1432090550661087
# -------------------------------
# Epoch: 6/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.06645209342241287
# -------------------------------
# Epoch: 6/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.01651371642947197
# -------------------------------
# Epoch: 6/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.028452042490243912
# -------------------------------
# Epoch: 6/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.09233956038951874
# -------------------------------
# Epoch: 6/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03318547457456589
# -------------------------------
# Epoch: 6/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08417478948831558
# -------------------------------
# Epoch: 6/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04962952062487602
# -------------------------------
# Epoch: 6/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.12491482496261597
# -------------------------------
# Epoch: 6/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.020194124430418015
# -------------------------------
# Epoch: 6/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.28517577052116394
# -------------------------------
# Epoch: 6/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07242079824209213
# -------------------------------
# Epoch: 6/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.19727009534835815
# -------------------------------
# Epoch: 6/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.27952390909194946
# -------------------------------
# Epoch: 6/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.014452315866947174
# -------------------------------
# Epoch: 6/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.02885776199400425
# -------------------------------
# Epoch: 6/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3164518177509308
# -------------------------------
# Epoch: 6/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.17471563816070557
# -------------------------------
# Epoch: 6/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.043268922716379166
# -------------------------------
# Epoch: 6/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3132740259170532
# -------------------------------
# Epoch: 7/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.16212306916713715
# -------------------------------
# Epoch: 7/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.13188323378562927
# -------------------------------
# Epoch: 7/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04311762750148773
# -------------------------------
# Epoch: 7/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08470720052719116
# -------------------------------
# Epoch: 7/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.23264232277870178
# -------------------------------
# Epoch: 7/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.011767534539103508
# -------------------------------
# Epoch: 7/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.11536633968353271
# -------------------------------
# Epoch: 7/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08732511848211288
# -------------------------------
# Epoch: 7/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.01543743722140789
# -------------------------------
# Epoch: 7/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0560317263007164
# -------------------------------
# Epoch: 7/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03941568732261658
# -------------------------------
# Epoch: 7/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.020976189523935318
# -------------------------------
# Epoch: 7/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1633334457874298
# -------------------------------
# Epoch: 7/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.10285091400146484
# -------------------------------
# Epoch: 7/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.041916243731975555
# -------------------------------
# Epoch: 7/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.006587562151253223
# -------------------------------
# Epoch: 7/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.016017291694879532
# -------------------------------
# Epoch: 7/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03788241371512413
# -------------------------------
# Epoch: 7/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.6956056356430054
# -------------------------------
# Epoch: 7/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.551074743270874
# -------------------------------
# Epoch: 7/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.032059937715530396
# -------------------------------
# Epoch: 8/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.18416033685207367
# -------------------------------
# Epoch: 8/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.037110649049282074
# -------------------------------
# Epoch: 8/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.14628498256206512
# -------------------------------
# Epoch: 8/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.10049577057361603
# -------------------------------
# Epoch: 8/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1797727644443512
# -------------------------------
# Epoch: 8/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.15120674669742584
# -------------------------------
# Epoch: 8/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.007876785472035408
# -------------------------------
# Epoch: 8/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0066392323933541775
# -------------------------------
# Epoch: 8/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.09609569609165192
# -------------------------------
# Epoch: 8/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.051694970577955246
# -------------------------------
# Epoch: 8/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.042727403342723846
# -------------------------------
# Epoch: 8/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.006570355501025915
# -------------------------------
# Epoch: 8/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.2231069803237915
# -------------------------------
# Epoch: 8/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.12299539148807526
# -------------------------------
# Epoch: 8/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08311212062835693
# -------------------------------
# Epoch: 8/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.026406267657876015
# -------------------------------
# Epoch: 8/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.05905264616012573
# -------------------------------
# Epoch: 8/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.12747323513031006
# -------------------------------
# Epoch: 8/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04834846779704094
# -------------------------------
# Epoch: 8/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0436115637421608
# -------------------------------
# Epoch: 8/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.014990809373557568
# -------------------------------
# Epoch: 9/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07811906933784485
# -------------------------------
# Epoch: 9/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.13655853271484375
# -------------------------------
# Epoch: 9/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.06694694608449936
# -------------------------------
# Epoch: 9/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.10772974789142609
# -------------------------------
# Epoch: 9/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03982944414019585
# -------------------------------
# Epoch: 9/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.15152888000011444
# -------------------------------
# Epoch: 9/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03407272696495056
# -------------------------------
# Epoch: 9/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.18041904270648956
# -------------------------------
# Epoch: 9/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03663625940680504
# -------------------------------
# Epoch: 9/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.14644646644592285
# -------------------------------
# Epoch: 9/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03706556558609009
# -------------------------------
# Epoch: 9/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.10011402517557144
# -------------------------------
# Epoch: 9/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.16659033298492432
# -------------------------------
# Epoch: 9/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.014195886440575123
# -------------------------------
# Epoch: 9/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07277042418718338
# -------------------------------
# Epoch: 9/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.233161062002182
# -------------------------------
# Epoch: 9/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04639998823404312
# -------------------------------
# Epoch: 9/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07741539180278778
# -------------------------------
# Epoch: 9/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.2390379160642624
# -------------------------------
# Epoch: 9/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.09723720699548721
# -------------------------------
# Epoch: 9/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.23671455681324005
# -------------------------------
# Epoch: 10/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07947862893342972
# -------------------------------
# Epoch: 10/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07879317551851273
# -------------------------------
# Epoch: 10/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03200561925768852
# -------------------------------
# Epoch: 10/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.048806317150592804
# -------------------------------
# Epoch: 10/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.042740948498249054
# -------------------------------
# Epoch: 10/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.011588877066969872
# -------------------------------
# Epoch: 10/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.19824495911598206
# -------------------------------
# Epoch: 10/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.4351040720939636
# -------------------------------
# Epoch: 10/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.10877418518066406
# -------------------------------
# Epoch: 10/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.09379320591688156
# -------------------------------
# Epoch: 10/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.35885339975357056
# -------------------------------
# Epoch: 10/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04535850137472153
# -------------------------------
# Epoch: 10/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.06286679208278656
# -------------------------------
# Epoch: 10/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.4494953155517578
# -------------------------------
# Epoch: 10/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0062124780379235744
# -------------------------------
# Epoch: 10/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.28590282797813416
# -------------------------------
# Epoch: 10/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.2712981700897217
# -------------------------------
# Epoch: 10/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04387609288096428
# -------------------------------
# Epoch: 10/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.02677018940448761
# -------------------------------
# Epoch: 10/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04293767362833023
# -------------------------------
# Epoch: 10/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.15154097974300385
# -------------------------------
# Epoch: 11/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1422554850578308
# -------------------------------
# Epoch: 11/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.014147341251373291
# -------------------------------
# Epoch: 11/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.045699723064899445
# -------------------------------
# Epoch: 11/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1596909463405609
# -------------------------------
# Epoch: 11/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.022314347326755524
# -------------------------------
# Epoch: 11/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03920314833521843
# -------------------------------
# Epoch: 11/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.06961740553379059
# -------------------------------
# Epoch: 11/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.044829707592725754
# -------------------------------
# Epoch: 11/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.4086485505104065
# -------------------------------
# Epoch: 11/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.026548629626631737
# -------------------------------
# Epoch: 11/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08156511187553406
# -------------------------------
# Epoch: 11/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.041871827095746994
# -------------------------------
# Epoch: 11/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.14581787586212158
# -------------------------------
# Epoch: 11/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.02043190784752369
# -------------------------------
# Epoch: 11/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03757800906896591
# -------------------------------
# Epoch: 11/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03140833228826523
# -------------------------------
# Epoch: 11/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1418921947479248
# -------------------------------
# Epoch: 11/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.09809618443250656
# -------------------------------
# Epoch: 11/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.16555623710155487
# -------------------------------
# Epoch: 11/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08294102549552917
# -------------------------------
# Epoch: 11/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.3199000060558319
# -------------------------------
# Epoch: 12/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0853625237941742
# -------------------------------
# Epoch: 12/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1428312063217163
# -------------------------------
# Epoch: 12/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1091172844171524
# -------------------------------
# Epoch: 12/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.05817842483520508
# -------------------------------
# Epoch: 12/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.16837523877620697
# -------------------------------
# Epoch: 12/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0370078980922699
# -------------------------------
# Epoch: 12/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1521492898464203
# -------------------------------
# Epoch: 12/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.06822840124368668
# -------------------------------
# Epoch: 12/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0290670283138752
# -------------------------------
# Epoch: 12/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.2586732506752014
# -------------------------------
# Epoch: 12/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07811130583286285
# -------------------------------
# Epoch: 12/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.10985743999481201
# -------------------------------
# Epoch: 12/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.054627060890197754
# -------------------------------
# Epoch: 12/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.06891180574893951
# -------------------------------
# Epoch: 12/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.17892183363437653
# -------------------------------
# Epoch: 12/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.019202211871743202
# -------------------------------
# Epoch: 12/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1672498881816864
# -------------------------------
# Epoch: 12/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.02239091508090496
# -------------------------------
# Epoch: 12/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.06897103786468506
# -------------------------------
# Epoch: 12/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.11364450305700302
# -------------------------------
# Epoch: 12/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07803522050380707
# -------------------------------
# Epoch: 13/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.022132253274321556
# -------------------------------
# Epoch: 13/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.13162508606910706
# -------------------------------
# Epoch: 13/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.22865471243858337
# -------------------------------
# Epoch: 13/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03136156499385834
# -------------------------------
# Epoch: 13/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.09113357216119766
# -------------------------------
# Epoch: 13/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.016533534973859787
# -------------------------------
# Epoch: 13/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.017343755811452866
# -------------------------------
# Epoch: 13/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.008701751008629799
# -------------------------------
# Epoch: 13/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.5109648704528809
# -------------------------------
# Epoch: 13/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.014714434742927551
# -------------------------------
# Epoch: 13/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.06723581254482269
# -------------------------------
# Epoch: 13/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.018207399174571037
# -------------------------------
# Epoch: 13/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.013770180754363537
# -------------------------------
# Epoch: 13/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03773925453424454
# -------------------------------
# Epoch: 13/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.12938109040260315
# -------------------------------
# Epoch: 13/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.10646764934062958
# -------------------------------
# Epoch: 13/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.02423878200352192
# -------------------------------
# Epoch: 13/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.24330449104309082
# -------------------------------
# Epoch: 13/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0426231250166893
# -------------------------------
# Epoch: 13/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.048261161893606186
# -------------------------------
# Epoch: 13/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.2933957874774933
# -------------------------------
# Epoch: 14/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.024152692407369614
# -------------------------------
# Epoch: 14/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.12726038694381714
# -------------------------------
# Epoch: 14/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08737261593341827
# -------------------------------
# Epoch: 14/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.008529940620064735
# -------------------------------
# Epoch: 14/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08001989126205444
# -------------------------------
# Epoch: 14/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.032085318118333817
# -------------------------------
# Epoch: 14/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.009505074471235275
# -------------------------------
# Epoch: 14/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.014958220534026623
# -------------------------------
# Epoch: 14/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.02237880602478981
# -------------------------------
# Epoch: 14/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.13153190910816193
# -------------------------------
# Epoch: 14/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.025465011596679688
# -------------------------------
# Epoch: 14/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.12019278109073639
# -------------------------------
# Epoch: 14/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.01418476365506649
# -------------------------------
# Epoch: 14/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1994480937719345
# -------------------------------
# Epoch: 14/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.028993159532546997
# -------------------------------
# Epoch: 14/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.053882896900177
# -------------------------------
# Epoch: 14/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.42307600378990173
# -------------------------------
# Epoch: 14/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.039981842041015625
# -------------------------------
# Epoch: 14/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.015087848529219627
# -------------------------------
# Epoch: 14/300
# Steps: 96
# ...
# Epoch: 296/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0027560056187212467
# -------------------------------
# Epoch: 296/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.006936650723218918
# -------------------------------
# Epoch: 296/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.004434166010469198
# -------------------------------
# Epoch: 296/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.11321331560611725
# -------------------------------
# Epoch: 296/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.05300172418355942
# -------------------------------
# Epoch: 296/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0004754304827656597
# -------------------------------
# Epoch: 296/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04082731157541275
# -------------------------------
# Epoch: 296/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03431643173098564
# -------------------------------
# Epoch: 296/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.028356146067380905
# -------------------------------
# Epoch: 296/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0024822340346872807
# -------------------------------
# Epoch: 296/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.006561446934938431
# -------------------------------
# Epoch: 296/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0027550242375582457
# -------------------------------
# Epoch: 297/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0018692903686314821
# -------------------------------
# Epoch: 297/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0030500409193336964
# -------------------------------
# Epoch: 297/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.00459290063008666
# -------------------------------
# Epoch: 297/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07022887468338013
# -------------------------------
# Epoch: 297/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1001489982008934
# -------------------------------
# Epoch: 297/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.004779711365699768
# -------------------------------
# Epoch: 297/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.05469771474599838
# -------------------------------
# Epoch: 297/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.4793568253517151
# -------------------------------
# Epoch: 297/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0683998093008995
# -------------------------------
# Epoch: 297/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.014455514028668404
# -------------------------------
# Epoch: 297/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0008109965128824115
# -------------------------------
# Epoch: 297/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.003470284165814519
# -------------------------------
# Epoch: 297/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0002478247624821961
# -------------------------------
# Epoch: 297/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.05111471936106682
# -------------------------------
# Epoch: 297/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.02304096333682537
# -------------------------------
# Epoch: 297/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08457569777965546
# -------------------------------
# Epoch: 297/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.029194902628660202
# -------------------------------
# Epoch: 297/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04034319892525673
# -------------------------------
# Epoch: 297/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.036049943417310715
# -------------------------------
# Epoch: 297/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0010605683783069253
# -------------------------------
# Epoch: 297/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.35336509346961975
# -------------------------------
# Epoch: 298/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0012588065583258867
# -------------------------------
# Epoch: 298/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1380019634962082
# -------------------------------
# Epoch: 298/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.00012872522347606719
# -------------------------------
# Epoch: 298/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.004593228455632925
# -------------------------------
# Epoch: 298/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.002591769676655531
# -------------------------------
# Epoch: 298/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.00011092795466538519
# -------------------------------
# Epoch: 298/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.01850110851228237
# -------------------------------
# Epoch: 298/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0029517796356230974
# -------------------------------
# Epoch: 298/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.004857765045017004
# -------------------------------
# Epoch: 298/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.029759015887975693
# -------------------------------
# Epoch: 298/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.12018869817256927
# -------------------------------
# Epoch: 298/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.050936419516801834
# -------------------------------
# Epoch: 298/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0442601814866066
# -------------------------------
# Epoch: 298/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.1427757441997528
# -------------------------------
# Epoch: 298/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.49435335397720337
# -------------------------------
# Epoch: 298/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.015391996130347252
# -------------------------------
# Epoch: 298/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0004265535972081125
# -------------------------------
# Epoch: 298/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0009959429735317826
# -------------------------------
# Epoch: 298/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0010901965433731675
# -------------------------------
# Epoch: 298/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.00275099603459239
# -------------------------------
# Epoch: 298/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.00015108594379853457
# -------------------------------
# Epoch: 299/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.060754455626010895
# -------------------------------
# Epoch: 299/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.02172010764479637
# -------------------------------
# Epoch: 299/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.00033891265047714114
# -------------------------------
# Epoch: 299/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.02128145657479763
# -------------------------------
# Epoch: 299/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.39110612869262695
# -------------------------------
# Epoch: 299/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.003649188671261072
# -------------------------------
# Epoch: 299/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 6.630815187236294e-05
# -------------------------------
# Epoch: 299/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04030716046690941
# -------------------------------
# Epoch: 299/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.08597985655069351
# -------------------------------
# Epoch: 299/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07889734208583832
# -------------------------------
# Epoch: 299/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0697767361998558
# -------------------------------
# Epoch: 299/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.002127242274582386
# -------------------------------
# Epoch: 299/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.023011842742562294
# -------------------------------
# Epoch: 299/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.06412087380886078
# -------------------------------
# Epoch: 299/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.04964431747794151
# -------------------------------
# Epoch: 299/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.006188640370965004
# -------------------------------
# Epoch: 299/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.033314622938632965
# -------------------------------
# Epoch: 299/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0017476205248385668
# -------------------------------
# Epoch: 299/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.014247303828597069
# -------------------------------
# Epoch: 299/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.03256619721651077
# -------------------------------
# Epoch: 299/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.007723147980868816
# -------------------------------
# Epoch: 300/300
# Steps: 1
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.07731866091489792
# -------------------------------
# Epoch: 300/300
# Steps: 6
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.003211386501789093
# -------------------------------
# Epoch: 300/300
# Steps: 11
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.28958645462989807
# -------------------------------
# Epoch: 300/300
# Steps: 16
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.005560607183724642
# -------------------------------
# Epoch: 300/300
# Steps: 21
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.002274820115417242
# -------------------------------
# Epoch: 300/300
# Steps: 26
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.011762828566133976
# -------------------------------
# Epoch: 300/300
# Steps: 31
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 1.4233763977244962e-05
# -------------------------------
# Epoch: 300/300
# Steps: 36
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.13824553787708282
# -------------------------------
# Epoch: 300/300
# Steps: 41
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.009340719319880009
# -------------------------------
# Epoch: 300/300
# Steps: 46
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.06318698078393936
# -------------------------------
# Epoch: 300/300
# Steps: 51
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.00041118040098808706
# -------------------------------
# Epoch: 300/300
# Steps: 56
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0007844112114980817
# -------------------------------
# Epoch: 300/300
# Steps: 61
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.035054728388786316
# -------------------------------
# Epoch: 300/300
# Steps: 66
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.023978296667337418
# -------------------------------
# Epoch: 300/300
# Steps: 71
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.0004429641121532768
# -------------------------------
# Epoch: 300/300
# Steps: 76
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.005691134836524725
# -------------------------------
# Epoch: 300/300
# Steps: 81
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.01479334570467472
# -------------------------------
# Epoch: 300/300
# Steps: 86
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.11397813260555267
# -------------------------------
# Epoch: 300/300
# Steps: 91
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.00012737748329527676
# -------------------------------
# Epoch: 300/300
# Steps: 96
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.007998957298696041
# -------------------------------
# Epoch: 300/300
# Steps: 101
# Batch Features shape: torch.Size([5, 30]) | Batch Target shape: torch.Size([5, 1])
# Loss: 0.007082323078066111

# %% [markdown]
# ## 4.4 Evaluation

# %%
# we also check the initial loss on the test data after training

from sklearn.metrics import accuracy_score

with torch.no_grad():
    # this gives the sigmoid output
    y_test_pred = model(X_test)
    # this assigns 1 if sigmoid op is >=0.5 and 0 o.w.
    y_test_hat = y_test_pred.round()
    print("Final Accuracy on test data:", accuracy_score(y_test, y_test_hat))
# Out:
# Final Accuracy on test data: 1.0

# %% [markdown]
# So, we manage to improve the test accuracy from `7%` to `100%`.

# %% [markdown]
# # 5. In-built datasets in PyTorch
#
# PyTorch comes with several built-in datasets, all of which are pre-loaded in the class `torch.datasets`. The package `torch` consists of all the core classes and methods required to implement neural networks, while `torchvision` is a supporting package consisting of popular datasets, model architectures, and common image transformations for computer vision. There is one more package named `torchtext` which has all the basic utilities of PyTorch Natural Language Processing. This package consists of datasets that are related to text.

# %% [markdown]
# ## 5.1 Datasets in TorchVision
#
# - **MNIST:** `torchvision.datasets.MNIST()`
# - **Fashion MNIST:** `torchvision.datasets.FashionMNIST()`
# - **CIFAR:** `torchvision.datasets.CIFAR10()`, `torchvision.datasets.CIFAR100()`
# - **COCO:** `torchvision.datasets.CocoCaptions()`
# - **EMNIST:** `torchvision.datasets.EMNIST()`
# - **IMAGE-NET:** `torchvision.datasets.ImageNet()`

# %% [markdown]
# ## 5.1 Datasets in TorchText
#
# - **IMDB:** `torchtext.datasets.IMDB()`
# - **WikiText2:** `torchtext.datasets.WikiText2()`

# %% [markdown]
# ## 5.3 `ImageFolder Class`
#
# `ImageFolder` is a generic data loader class in `torchvision` that helps you load your own image dataset. Let’s imagine you are working on a classification problem and building a neural network to identify if a given image is an apple or an orange. To do this in PyTorch, the first step is to arrange images in a default folder structure as shown below:
# ```
#  root
# ├── orange
# │   └── orange_image1.png
# │   └── orange_image1.png
# ├── apple
# │   └── apple_image1.png
# │   └── apple_image2.png
# │   └── apple_image3.png
# ```
# After we have arranged our dataset as shown, we can use the `ImageLoader` class to load all these images. Below is the code snippet you would use to do so:
# ```Python
# torchvision.datasets.ImageFolder(root, transform)
# ```

# %%
# %%time
